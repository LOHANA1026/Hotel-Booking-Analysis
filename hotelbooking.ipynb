# %% [markdown]
# # Project Name - Hotel-Booking-Analysis

# %% [markdown]
# Project Type - EDA
#
# Contribution - Individual

# %% [markdown]
# # Project Summary

# %% [markdown]
# In our "Hotel Booking Analysis" project, we delve into a dataset comprising booking information for both city and resort hotels. This dataset contains 119,390 rows and 32 columns, offering a wealth of information about hotel bookings. The dataset is stripped of any personally identifying information, ensuring data privacy.
#
# Our primary objective is to perform Exploratory Data Analysis (EDA) using Python to gain valuable insights from this dataset. EDA is the initial phase in the data science process, where we seek to understand the data, identify patterns, and extract meaningful information. Through this analysis, we aim to answer questions and discover trends that can help hotel managers and stakeholders make informed decisions to enhance their services and maximize profitability.
#
# The dataset's columns provide a comprehensive view of the booking details. Information such as booking dates, length of stay, the number of adults, children, and babies, and the availability of parking spaces are included, among others. By leveraging numerical programming in Python, we can extract, visualize, and interpret this data to uncover hidden patterns.
#
# Our analysis will begin by addressing fundamental questions:
#
# When are bookings made? We will explore booking patterns over time to identify peak booking periods and seasonality.
#
# How long do guests stay? Analyzing the length of stay can help hotels optimize room turnover and pricing strategies.
#
# Who are the guests? Understanding the composition of guests, such as the number of adults, children, and babies, can influence room allocation and amenity provision.
#
# Are parking spaces utilized efficiently? We will assess the demand for parking and its impact on guest satisfaction.
#
# Throughout our project, we'll employ Python libraries such as Pandas, Matplotlib, and Seaborn to preprocess, visualize, and analyze the data. We will create informative graphs, charts, and statistical summaries to make the insights easily understandable. This data-driven approach empowers hotel managers to make data-informed decisions that can enhance guest experiences and improve overall hotel operations.
#
# The ultimate goal of our "Hotel Booking Analysis" project is to provide actionable recommendations based on data-backed insights. These recommendations may encompass pricing strategies, marketing efforts, resource allocation, and guest experience enhancements. By leveraging the power of data science and Python programming, we aim to help hotels maximize their efficiency, profitability, and guest satisfaction while optimizing their services for future success.
#
# As we embark on this data analysis journey, our aim is to transform raw data into knowledge and insights, making the "Hotel Booking Analysis" project a valuable asset for the hospitality industry.

# %% [markdown]
# # GitHub Link

# %% [markdown]
# https://github.com/LOHANA1026/Hotel-Booking-Analysis

# %% [markdown]
# # Problem Statement

# %% [markdown]
# In our "Hotel Booking Analysis" project, we aim to gain valuable insights from a dataset containing booking information for both city and resort hotels, consisting of 119,390 rows and 32 columns. This dataset offers details on when bookings were made, the duration of stays, the number of guests (adults, children, and babies), parking availability, and more. Importantly, all personally identifying information has been removed to ensure data privacy. Our primary objective is to conduct an Exploratory Data Analysis (EDA) using numerical programming in Python. Through this analysis, we intend to answer questions and uncover patterns that can inform decision-making within the hospitality industry. We'll explore booking trends, guest demographics, length of stay, and parking space utilization, ultimately providing actionable insights to enhance hotel services, optimize operations, and improve guest satisfaction. This project combines data science with Python programming to transform raw data into valuable knowledge, benefiting hotel management and operations.

# %% [markdown]
# # Let's Begin !

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
# Importing neccesary libraries.

import pandas as pd
import seaborn as sns
import numpy as np
from matplotlib import pyplot as plt
# %matplotlib inline
from sklearn.preprocessing import StandardScaler
pd.set_option('display.max_columns', 1000)

# %% [markdown]
# # 1. Reading and Inspection

# %%
#mounting the data set
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Load Dataset
path = '/content/drive/My Drive/Almabetter Project/EDA - hotel booking/HB.csv'

df = pd.read_csv(path)

# %%
df.head()
# Out:
#           hotel  is_canceled  lead_time  arrival_date_year arrival_date_month  \
# 0  Resort Hotel            0        342               2015               July
# 1  Resort Hotel            0        737               2015               July
# 2  Resort Hotel            0          7               2015               July
# 3  Resort Hotel            0         13               2015               July
# 4  Resort Hotel            0         14               2015               July
#
#    arrival_date_week_number  arrival_date_day_of_month  \
# 0                        27                          1
# 1                        27                          1
# 2                        27                          1
# 3                        27                          1
# 4                        27                          1
#
#    stays_in_weekend_nights  stays_in_week_nights  adults  children  babies  \
# 0                        0                     0       2       0.0       0
# ...

# %%
print(df.shape)
# Out:
# (119390, 32)

# %%
# let's look at the statistical aspects of the dataframes
df.describe()
# Out:
#          is_canceled      lead_time  arrival_date_year  \
# count  119390.000000  119390.000000      119390.000000
# mean        0.370416     104.011416        2016.156554
# std         0.482918     106.863097           0.707476
# min         0.000000       0.000000        2015.000000
# 25%         0.000000      18.000000        2016.000000
# 50%         0.000000      69.000000        2016.000000
# 75%         1.000000     160.000000        2017.000000
# max         1.000000     737.000000        2017.000000
#
#        arrival_date_week_number  arrival_date_day_of_month  \
# count             119390.000000              119390.000000
# mean                  27.165173                  15.798241
# std                   13.605138                   8.780829
# min                    1.000000                   1.000000
# 25%                   16.000000                   8.000000
# 50%                   28.000000                  16.000000
# ...

# %%
#checking datatypes
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 119390 entries, 0 to 119389
# Data columns (total 32 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   hotel                           119390 non-null  object
#  1   is_canceled                     119390 non-null  int64
#  2   lead_time                       119390 non-null  int64
#  3   arrival_date_year               119390 non-null  int64
#  4   arrival_date_month              119390 non-null  object
#  5   arrival_date_week_number        119390 non-null  int64
#  6   arrival_date_day_of_month       119390 non-null  int64
#  7   stays_in_weekend_nights         119390 non-null  int64
#  8   stays_in_week_nights            119390 non-null  int64
#  9   adults                          119390 non-null  int64
#  10  children                        119386 non-null  float64
#  11  babies                          119390 non-null  int64
# ...

# %% [markdown]
# ###The dataset have 32 variables (Continuous and Categorical) with one identified dependent variable (categorical), which is 'is_cancelled.

# %%
# Enlarging the pie chart
plt.rcParams['figure.figsize'] = 8,8

# Indexing labels. tolist() will convert the index to list for easy manipulation
labels = df['hotel'].value_counts().index.tolist()

# Convert value counts to list
sizes = df['hotel'].value_counts().tolist()

# As the name suggest, explode will determine how much each section is separated from each other
explode = (0, 0.1)

# Determine colour of pie chart
colors = ['yellowgreen', 'lightcoral']

plt.pie(sizes, explode=explode, labels=labels, colors=colors, autopct='%1.1f%%',startangle=90, textprops={'fontsize': 14})
plt.show()

# %% [markdown]
# *   We can see that the percent of City hotel is more compared to Resort hotel.
#
# *   Resort Hotel tend to be on the expensive side and most people will just stick with city hotel.

# %% [markdown]
# #`2. Cleaning the Data`

# %%
#Checking the missing values in the columns

df.isnull().sum()
# Out:
# hotel                                  0
# is_canceled                            0
# lead_time                              0
# arrival_date_year                      0
# arrival_date_month                     0
# arrival_date_week_number               0
# arrival_date_day_of_month              0
# stays_in_weekend_nights                0
# stays_in_week_nights                   0
# adults                                 0
# children                               4
# babies                                 0
# meal                                   0
# country                              488
# market_segment                         0
# distribution_channel                   0
# is_repeated_guest                      0
# previous_cancellations                 0
# previous_bookings_not_canceled         0
# reserved_room_type                     0
# assigned_room_type                     0
# booking_changes                        0
# deposit_type                           0
# ...

# %%
#Column-wise null percentage

print(round(100*(df.isnull().sum()/len(df.index)),2))
# Out:
# hotel                              0.00
# is_canceled                        0.00
# lead_time                          0.00
# arrival_date_year                  0.00
# arrival_date_month                 0.00
# arrival_date_week_number           0.00
# arrival_date_day_of_month          0.00
# stays_in_weekend_nights            0.00
# stays_in_week_nights               0.00
# adults                             0.00
# children                           0.00
# babies                             0.00
# meal                               0.00
# country                            0.41
# market_segment                     0.00
# distribution_channel               0.00
# is_repeated_guest                  0.00
# previous_cancellations             0.00
# previous_bookings_not_canceled     0.00
# reserved_room_type                 0.00
# assigned_room_type                 0.00
# booking_changes                    0.00
# deposit_type                       0.00
# ...

# %% [markdown]
# ##The dataset contains Missing values .
# * Drop unecessary columns:
#
#
# ##Lets drop columns with high missing values.

# %%
df=df.drop(['agent','company'],axis=1)

# %% [markdown]
# * Country has 488 rows with the NaN values. 488 rows out of 119390 is negligible hence we will just remove.

# %%
df = df.dropna(axis = 0)

# %%
df.isnull().sum()
# Out:
# hotel                             0
# is_canceled                       0
# lead_time                         0
# arrival_date_year                 0
# arrival_date_month                0
# arrival_date_week_number          0
# arrival_date_day_of_month         0
# stays_in_weekend_nights           0
# stays_in_week_nights              0
# adults                            0
# children                          0
# babies                            0
# meal                              0
# country                           0
# market_segment                    0
# distribution_channel              0
# is_repeated_guest                 0
# previous_cancellations            0
# previous_bookings_not_canceled    0
# reserved_room_type                0
# assigned_room_type                0
# booking_changes                   0
# deposit_type                      0
# days_in_waiting_list              0
# customer_type                     0
# adr                               0
# ...

# %% [markdown]
# * No more missing values in the data

# %% [markdown]
# ### Lets Rename the columns for better readability

# %%
df.columns = ['Hotel', 'Canceled', 'LeadTime', 'ArrivingYear', 'ArrivingMonth', 'ArrivingWeek','ArrivingDate', 'WeekendStay',
              'WeekStay', 'Adults', 'Children', 'Babies', 'Meal','Country', 'Segment', 'DistChannel','RepeatGuest', 'PrevCancel',
              'PrevBook', 'BookRoomType','AssignRoomType', 'ChangeBooking', 'DepositType', 'WaitingDays',
              'CustomerType', 'ADR','ParkSpace', 'SpecialRequest','Reservation', 'ReservationDate']

# %% [markdown]
# ##Identify Continuous and Categorical Variables

# %%
def var(df):
    unique_list = pd.DataFrame([[i,len(df[i].unique())] for i in df.columns])
    unique_list.columns = ['name','uniques']

    total_var = set(df.columns)
    cat_var = set(unique_list.name[(unique_list.uniques<=12)      |
                                   (unique_list.name=='Country')  |
                                   (unique_list.name=='Agent')
                                  ])
    con_var = total_var - cat_var

    return cat_var, con_var


cat_var, con_var = var(df)

print("Continuous Variables (",len(con_var),")\n",con_var,'\n\n'
      "Categorical Variables(",len(cat_var),")\n",cat_var)
# Out:
# Continuous Variables ( 12 )
#  {'WeekendStay', 'ReservationDate', 'ArrivingDate', 'LeadTime', 'ArrivingWeek', 'PrevBook', 'WeekStay', 'ChangeBooking', 'PrevCancel', 'ADR', 'Adults', 'WaitingDays'}
#
# Categorical Variables( 18 )
#  {'RepeatGuest', 'DistChannel', 'CustomerType', 'ParkSpace', 'Hotel', 'Babies', 'Children', 'BookRoomType', 'ArrivingYear', 'AssignRoomType', 'ArrivingMonth', 'SpecialRequest', 'Country', 'Meal', 'Canceled', 'DepositType', 'Reservation', 'Segment'}

# %% [markdown]
# ###### Checking the Outliers

# %%
# Creating a boxplot for Outlier detection
features = ['LeadTime', 'WeekendStay', 'WeekStay', 'Adults','Children', 'Babies','ADR']
n = 1
plt.figure(figsize=(16,18))
for feature in features:
    plt.subplot(4,4,n)
    sns.boxplot(df[features])
    n+=1
    plt.tight_layout()

# %% [markdown]
# * The dataset contains Outliers.

# %%
#Checking outliers in continuous variables
df[con_var].describe()
# Out:
#          WeekendStay   ArrivingDate       LeadTime   ArrivingWeek  \
# count  118898.000000  118898.000000  118898.000000  118898.000000
# mean        0.928897      15.800880     104.311435      27.166555
# std         0.996216       8.780324     106.903309      13.589971
# min         0.000000       1.000000       0.000000       1.000000
# 25%         0.000000       8.000000      18.000000      16.000000
# 50%         1.000000      16.000000      69.000000      28.000000
# 75%         2.000000      23.000000     161.000000      38.000000
# max        16.000000      31.000000     737.000000      53.000000
#
#             PrevBook       WeekStay  ChangeBooking     PrevCancel  \
# count  118898.000000  118898.000000  118898.000000  118898.000000
# mean        0.131634       2.502145       0.221181       0.087142
# std         1.484672       1.900168       0.652785       0.845869
# min         0.000000       0.000000       0.000000       0.000000
# ...

# %% [markdown]
# ### List of Continuous Variables with Outliers identified through Summary Statistics are:
#
# * LeadTime
# * WaitingDays
# * WeekendStay
# * Adults
# * PrevBook
# * PrevCancel
# * WeekStay
# ### List of Continuous Variables which should be Categorical
# * PrevBook
# * PrevCancel

# %% [markdown]
# * Imputing the Outliers (for Continuous Variable)

# %%
df.loc[df.LeadTime      > 500,'LeadTime'     ]=500
df.loc[df.WaitingDays   >   0,'WaitingDays'  ]=  1
df.loc[df.WeekendStay   >=  5,'WeekendStay'  ]=  5
df.loc[df.Adults        >   4,'Adults'       ]=  4
df.loc[df.PrevBook      >   0,'PrevBook'     ]=  1
df.loc[df.PrevCancel    >   0,'PrevCancel'   ]=  1
df.loc[df.WeekStay      >  10,'WeekStay'     ]= 10
df.loc[df.ChangeBooking >   5,'ChangeBooking']=  5

cat_var = set(list(cat_var) + ['PrevBook','PrevCancel'])
con_var = set(df.columns) - cat_var

df[con_var].describe()
# Out:
#          WeekendStay   ArrivingDate       LeadTime   ArrivingWeek  \
# count  118898.000000  118898.000000  118898.000000  118898.000000
# mean        0.924187      15.800880     104.054543      27.166555
# std         0.967762       8.780324     105.834923      13.589971
# min         0.000000       1.000000       0.000000       1.000000
# 25%         0.000000       8.000000      18.000000      16.000000
# 50%         1.000000      16.000000      69.000000      28.000000
# 75%         2.000000      23.000000     161.000000      38.000000
# max         5.000000      31.000000     500.000000      53.000000
#
#             WeekStay  ChangeBooking            ADR         Adults  \
# count  118898.000000  118898.000000  118898.000000  118898.000000
# mean        2.481581       0.217237     102.003243       1.855607
# std         1.760766       0.602693      50.485862       0.488194
# min         0.000000       0.000000      -6.380000       0.000000
# ...

# %%
#outliers in categorical variables
df[cat_var].describe()
# Out:
#          RepeatGuest       Canceled         Babies       PrevBook  \
# count  118898.000000  118898.000000  118898.000000  118898.000000
# mean        0.032011       0.371352       0.007948       0.028571
# std         0.176029       0.483168       0.097380       0.166597
# min         0.000000       0.000000       0.000000       0.000000
# 25%         0.000000       0.000000       0.000000       0.000000
# 50%         0.000000       0.000000       0.000000       0.000000
# 75%         0.000000       1.000000       0.000000       0.000000
# max         1.000000       1.000000      10.000000       1.000000
#
#         ArrivingYear      ParkSpace  SpecialRequest     PrevCancel  \
# count  118898.000000  118898.000000   118898.000000  118898.000000
# mean     2016.157656       0.061885        0.571683       0.054223
# std         0.707459       0.244172        0.792678       0.226458
# min      2015.000000       0.000000        0.000000       0.000000
# ...

# %%
df.loc[df.Babies    > 8,'Babies']    = 0
df.loc[df.ParkSpace > 5,'ParkSpace'] = 0
df.loc[df.Children  > 8,'Children']  = 0

df[cat_var].describe()
# Out:
#          RepeatGuest       Canceled         Babies       PrevBook  \
# count  118898.000000  118898.000000  118898.000000  118898.000000
# mean        0.032011       0.371352       0.007788       0.028571
# std         0.176029       0.483168       0.089236       0.166597
# min         0.000000       0.000000       0.000000       0.000000
# 25%         0.000000       0.000000       0.000000       0.000000
# 50%         0.000000       0.000000       0.000000       0.000000
# 75%         0.000000       1.000000       0.000000       0.000000
# max         1.000000       1.000000       2.000000       1.000000
#
#         ArrivingYear      ParkSpace  SpecialRequest     PrevCancel  \
# count  118898.000000  118898.000000   118898.000000  118898.000000
# mean     2016.157656       0.061750        0.571683       0.054223
# std         0.707459       0.241992        0.792678       0.226458
# min      2015.000000       0.000000        0.000000       0.000000
# ...

# %% [markdown]
# * Now we have treated the outliers

# %% [markdown]
# # `3. Data Preparation`

# %%
#Lets combine children and babies together as kids
df['Kids'] = df.Children + df.Babies

#Combine total mumbers by adding kids and adults
df['total_members'] = df.Kids + df.Adults

# %%
#convert the datatypes to string
df['ArrivingYear'] = df['ArrivingYear'].astype('str')
df['ArrivingMonth'] = df['ArrivingMonth'].astype('str')
df['ArrivingDate'] = df['ArrivingDate'].astype('str')

df['Canceled'] = df['Canceled'].astype('str')
df['RepeatGuest'] = df['RepeatGuest'].astype('str')

# %%
# Lets convert arrival date to datetime
df['Arrival Date'] = df['ArrivingDate'] + '-' + df['ArrivingMonth'] + '-' + df['ArrivingYear']
df['Arrival Date'] = pd.to_datetime(df['Arrival Date'], errors='coerce')

# %%
confirmed_bookings = df[df.Canceled=='0']

# %%
import datetime as dt
confirmed_bookings['ArrivingMonth'] = df['Arrival Date'].dt.month
final=confirmed_bookings['ArrivingMonth'].value_counts().sort_index()
final
# Out:
# 1     4068
# 2     5317
# 3     6591
# 4     6533
# 5     7102
# 6     6393
# 7     7892
# 8     8618
# 9     6367
# 10    6867
# 11    4632
# 12    4365
# Name: ArrivingMonth, dtype: int64

# %% [markdown]
# ## Cancelations

# %%
print('Total Bookings canceled')
print('-'*50)
print(df.Canceled.value_counts())
print('-'*50)
print('*'*75)
print('Cancelation percentage in both hotels ')
print('-'*50)
print(df.Canceled.value_counts(normalize=True))
# Out:
# Total Bookings canceled
# --------------------------------------------------
# 0    74745
# 1    44153
# Name: Canceled, dtype: int64
# --------------------------------------------------
# ***************************************************************************
# Cancelation percentage in both hotels
# --------------------------------------------------
# 0    0.628648
# 1    0.371352
# Name: Canceled, dtype: float64

# %% [markdown]
# * 44153 bookings were canceled which is around 37%

# %% [markdown]
# ## Country

# %%
df.Country.value_counts(normalize=True)
# Out:
# PRT    0.408636
# GBR    0.102012
# FRA    0.087596
# ESP    0.072062
# DEU    0.061288
#          ...
# DJI    0.000008
# BWA    0.000008
# HND    0.000008
# VGB    0.000008
# NAM    0.000008
# Name: Country, Length: 177, dtype: float64

# %% [markdown]
# * Around 40% of all bookings were booked from Portugal followed by Great Britain(10%) & France(8%).

# %% [markdown]
# ##Month

# %%
df.ArrivingMonth.value_counts(normalize=True)
# Out:
# August       0.116503
# July         0.106209
# May          0.099068
# October      0.093315
# April        0.092895
# June         0.091902
# September    0.088033
# March        0.081911
# February     0.067385
# November     0.056788
# December     0.056586
# January      0.049404
# Name: ArrivingMonth, dtype: float64

# %% [markdown]
# * August is the most occupied (busiest) month with 11.62% bookings and January is the most unoccupied month with 4.96% bookings.

# %% [markdown]
# ## Market Segment

# %%
df.Segment.value_counts(normalize=True)
# Out:
# Online TA        0.474373
# Offline TA/TO    0.203199
# Groups           0.166580
# Direct           0.104695
# Corporate        0.042986
# Complementary    0.006173
# Aviation         0.001993
# Name: Segment, dtype: float64

# %% [markdown]
# * Around 47% of bookings are made via Online Travel Agents, almost 20% of bookings are made via Offline Travel Agents and less than 20% are Direct bookings without any other agents.

# %% [markdown]
# ## Year

# %%
df.ArrivingYear.value_counts(normalize=True)
# Out:
# 2016    0.474651
# 2017    0.341503
# 2015    0.183847
# Name: ArrivingYear, dtype: float64

# %% [markdown]
# * 47% bookings were done in 2016, 34% in 2017 and 18 percent in 2015.. We can see increasing tendency in bookings year wise

# %% [markdown]
# ## Meal

# %%
df.Meal.value_counts(normalize=True)
# Out:
# BB           0.772620
# HB           0.121398
# SC           0.089472
# Undefined    0.009798
# FB           0.006712
# Name: Meal, dtype: float64

# %% [markdown]
# * Out of the meals, BB (Bed & Breakfast) is the most ordered meal which is around 77.2%, followed by HB(Half Board), SC(no meal package), Undefined and FB (Full Board).

# %% [markdown]
# ## Customer Type

# %%
df.CustomerType.value_counts(normalize=True)
# Out:
# Transient          0.750004
# Transient-Party    0.210920
# Contract           0.034281
# Group              0.004794
# Name: CustomerType, dtype: float64

# %% [markdown]
# * Transient type of customers are the more around 75%

# %%
df.Reservation.value_counts(normalize=True)
# Out:
# Check-Out    0.628648
# Canceled     0.361234
# No-Show      0.010118
# Name: Reservation, dtype: float64

# %% [markdown]
# * We can see 63% visitors checked out and 36% bookings were canceled

# %% [markdown]
# # `4. Data Visualization`

# %%
plt.figure(figsize=(6,6))
sns.barplot(x='ArrivingYear', y='LeadTime',hue='Canceled', data= df, palette='vlag')
plt.title('Arriving year, Leadtime and Cancelations')
# Out:
# Text(0.5, 1.0, 'Arriving year, Leadtime and Cancelations')

# %% [markdown]
# * For all the 3 years, bookings with a lead time less than 100 days have fewer chances of getting canceled, and lead time more than 100 days have more chances of getting canceled.

# %%
#Lets see the correlation
plt.figure(figsize=(12,8))
sns.heatmap(df.corr(),annot=True,cmap='RdYlGn')
# Out:
# <Axes: >

# %% [markdown]
# ### Cancelled

# %%
#Canceled=1, Not canceled= 0

sns.countplot(x='Canceled',data=df)

plt.show()

# %% [markdown]
# * Majority of bookings were not canceled, still some half of the bookings were canceled

# %%
cols = ['green', 'red']
plt.figure(figsize=(6,8))
df['Canceled'].value_counts().plot.pie(autopct='%1.1f%%',shadow=True, colors=cols)
# Out:
# <Axes: ylabel='Canceled'>

# %% [markdown]
# * According to the pie chart, 63% of bookings were not canceled and 37% of the bookings were canceled at the Hotel.

# %%
plt.figure(figsize=(6, 6))

sns.countplot(x='Hotel',hue="Canceled", data=df,palette='Pastel1')
plt.title("Cancelation rates in City hotel and Resort hotel",fontweight="bold", size=20)
plt.show()

# %% [markdown]
# * Most bookings were in city hotel
# * Cancelations in Resort hotel is less compared to city hotel

# %% [markdown]
# ### Arrivals in month and year

# %%
plt.figure(figsize=(15, 8))
plt.subplot(1, 2, 1)
sns.countplot(x='ArrivingYear',hue='Hotel', data=df,palette='husl')
plt.title("Arrivals per year in Both hotels ",fontweight="bold", size=20)
plt.subplot(1, 2, 2)
sns.countplot(data = df, x = 'ArrivingMonth')
plt.title('Arrivals per month',fontweight="bold", size=20)
plt.subplots_adjust(right=1.7)

plt.show()

# %% [markdown]
# * We can see most of the bookings were in the year 2016 and bookings were doine in City hotel
# * Most bookings were done in the month of May,June, July, August

# %% [markdown]
# ### Arrivarl Date

# %%
plt.figure(figsize=(15,6))

sns.countplot(data = df, x = 'ArrivingDate', hue='Hotel', palette='Paired')
plt.show()

# %% [markdown]
# * Month end day has very less arrivals
# * Bookings are more in City hotel

# %% [markdown]
# ### Weekend Stay

# %%
plt.figure(figsize=(15, 8))
plt.subplot(1, 2, 1)
sns.countplot(x='WeekendStay',hue='Hotel', data=df, palette='cool')
plt.title("Number of stays on weekend nights",fontweight="bold", size=20)
plt.subplot(1, 2, 2)
sns.countplot(data = df, x = 'WeekendStay', hue='Canceled', palette='rocket')
plt.title('WeekendStay vs Cancelation',fontweight="bold", size=20)
plt.subplots_adjust(right=1.7)

plt.show()

# %% [markdown]
#  * In the first graph we can see that most of the weekend nights were booked in City Hotel
#
# * Second plot shows most of weekend nights which were booked were not canceled

# %% [markdown]
# ###WeekStay

# %%
plt.figure(figsize=(15, 8))
plt.subplot(1, 2, 1)
sns.countplot(x='WeekStay',hue='Hotel', data=df, palette='rainbow_r')
plt.title("Number of stays on weekday nights",fontweight="bold", size=20)
plt.subplot(1, 2, 2)
sns.countplot(data = df, x = 'WeekStay', hue='Canceled', palette='magma_r')
plt.title('WeekStay vs Cancelations',fontweight="bold", size=20)
plt.subplots_adjust(right=1.7)


plt.show()

# %% [markdown]
# * Weekday night stays were more in City Hotel
# * Less cancelations were observed

# %% [markdown]
# ### Adults

# %%
plt.figure(figsize=(15, 8))
plt.subplot(1, 2, 1)
sns.countplot(x='Adults',hue='Hotel', data=df, palette='pastel')
plt.title("Number of adults in both hotels",fontweight="bold", size=20)
plt.subplot(1, 2, 2)
sns.countplot(data = df, x = 'Adults', hue='Canceled', palette='husl')
plt.title('Adults vs Cancelations',fontweight="bold", size=20)
plt.subplots_adjust(right=1.7)


plt.show()

# %% [markdown]
# * Adults who were 2 in number are more and preferred city hotel rather than resort hotel, infact more than half the visitors even canceled the bookings

# %% [markdown]
# ### Children

# %%
plt.figure(figsize=(15, 8))
plt.subplot(1, 2, 1)
sns.countplot(x='Children',hue='Hotel', data=df, palette='cool')
plt.title("Number of Children in both hotels",fontweight="bold", size=20)
plt.subplot(1, 2, 2)
sns.countplot(data = df, x = 'Children', hue='Canceled', palette='Set2')
plt.title('Children vs Cancelations',fontweight="bold", size=20)
plt.subplots_adjust(right=1.7)


plt.show()

# %% [markdown]
# ### Babies

# %%
plt.figure(figsize=(15, 8))
plt.subplot(1, 2, 1)
sns.countplot(x='Babies',hue='Hotel', data=df, palette='coolwarm')
plt.title("Number of Babies in both hotels",fontweight="bold", size=20)

plt.subplot(1, 2, 2)
sns.countplot(data = df, x = 'Babies', hue='Canceled', palette='Set1_r')
plt.title('Babies vs Cancelations',fontweight="bold", size=20)
plt.subplots_adjust(right=1.7)



plt.show()

# %% [markdown]
# * Most visitors were arrived in pair with no children/ Babies and preferred City hotel over resort hotel
# * visitors who had 1 or 2 children also preferred city hotel

# %% [markdown]
# ### Country

# %%
import plotly.express as px
import plotly.graph_objects as go
import plotly.figure_factory as ff
from plotly.colors import n_colors
from plotly.subplots import make_subplots
# Minmax scaler
from sklearn.preprocessing import MinMaxScaler

# %%
country_visitors = df[df['Canceled'] == '0'].groupby(['Country']).size().reset_index(name = 'count')


import plotly.express as px

px.choropleth(country_visitors,
                    locations = "Country",
                    color= "count" ,
                    hover_name= "Country", # column to add to hover information
                    color_continuous_scale="Viridis",
                    title="Home country of visitors")
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# * More visitors are from western europe, namely France,UK and Portugal being the highest.

# %% [markdown]
# ### Market

# %%
plt.figure(figsize=(15, 8))
plt.subplot(1, 2, 1)
sns.countplot(x='Segment', data=df, palette='rocket')
plt.title('Types of market segment',fontweight="bold", size=20)

plt.subplot(1, 2, 2)
sns.countplot(data = df, x = 'DistChannel',  palette='Set1_r')
plt.title('Types of distribution channels',fontweight="bold", size=20)
plt.subplots_adjust(right=1.7)



plt.show()

# %% [markdown]
# * Majority DIstribution channels and Market segment were Travel agencies wither offline/online. So better focus more on this

# %% [markdown]
# ### Deposit

# %%
plt.figure(figsize=(12, 6))

sns.countplot(data = df, x = 'DepositType',hue='Hotel', palette='cool')
plt.title('Types of Deposit type',fontweight="bold", size=20)


plt.show()

# %% [markdown]
# * There was no deposit for City hotel where as Resorts had some deposits. No deposit may lead to cancel the bookings

# %% [markdown]
# ### Repeat Guest

# %%
plt.figure(figsize=(6,6))
sns.countplot(data = df, x = 'RepeatGuest', hue = 'RepeatGuest').set_title('Graph showing whether guest is repeated guest', fontsize = 20)
plt.show()

# %% [markdown]
# * Low number of repeated guests.
# * A need to target repeated guests since they have booked before.

# %% [markdown]
# ### Looking into prices per month per hotel
# * average daily rate =  SumOfAllLodgingTransaction/TotalNumberOfStayingNight
#
# * average daily rate per person =  ADR/Adults+Children
#
# * We will need to find out average daily rate per person

# %%
# Resizing plot
plt.figure(figsize=(12,5))

# Calculating average daily rate per person
df['adr_pp'] = df['ADR'] / (df['Adults'] + df['Children'])
actual_guests = df.loc[df["Canceled"] == '0']
actual_guests['price'] = actual_guests['ADR'] * (actual_guests['WeekendStay'] + actual_guests['WeekStay'])
sns.lineplot(data = actual_guests, x = 'ArrivingMonth', y = 'price', hue = 'Hotel')
plt.show()

# %% [markdown]
# * Prices of resort hotel are much higher.
# * Prices of city hotel do not fluctuate that much.

# %% [markdown]
# ### ADR: Average Daily Rate

# %%
plt.figure(figsize=(12,6))
sns.lineplot(x='ArrivingMonth', y='ADR', hue='Hotel', data= df)
plt.show()

# %% [markdown]
# * For Resort Hotel, ADR is more expensive during July, August & September and for City Hotel, ADR is slightly more during March, April & May.

# %% [markdown]
# ## Summary

# %% [markdown]
# * Majority of the hotels booked are city hotel. Definitely need to spend the most targeting fund on those hotel.
# * We also realise that the high rate of cancellations can be due high no deposit policies.
# * We should also target months between May to Aug. Those are peak months due to the summer period.
# * Majority of the guests are from Western Europe. We should spend a significant amount of our budget on those area.
# * Given that we do not have repeated guests, we should target our advertisement on guests to increase returning guests.

# %% [markdown]
# ## Strategies to Counter High Cancellations at the Hotel

# %% [markdown]
# * Set Non-refundable Rates, Collect deposits, and implement more rigid cancellation policies.
# * Encourage Direct bookings by offering special discounts
# * Monitor where the cancellations are coming from such as Market Segment, distribution channels, etc.
